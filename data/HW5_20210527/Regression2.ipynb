# %%
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import sklearn.metrics as metrics
from sklearn.naive_bayes import BernoulliNB
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.ensemble import BaggingRegressor
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error

# %%
data=pd.read_csv("train_regression.csv")
data.head()

col=['acid0','acid1','acid2','chlorides','sulphates0','sulphates1','sulphates2','density']
X=data[col]
y=data['score']
print(data)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("bmh")
from sklearn import preprocessing
from sklearn.svm import SVR
from sklearn import utils
from sklearn.tree import DecisionTreeRegressor


# model
from sklearn.ensemble import RandomForestRegressor
import optuna
from sklearn.ensemble import BaggingRegressor

from sklearn.linear_model import Lasso
# misc
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn import metrics


data=pd.read_csv("train_regression.csv")
data.head()



col=['acid0','acid1','acid2','chlorides','sulphates0','sulphates1','sulphates2','density']
X=data.iloc[:, :-1]
y=data['score']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25, random_state=27)



model = BaggingRegressor(
                                base_estimator= DecisionTreeRegressor(max_depth=140),
                                 n_estimators = 200
                                 ,
                                 max_samples = 1.0,
                                 max_features = 1.0
                        ) 

model.fit(X_train, y_train) 
accuracy = sqrt(mean_squared_error(model.predict(X_test), y_test))


accuracy
# Out:
# 11.45186989104541

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor



test=pd.read_csv("test_regression.csv")
data=pd.read_csv("train_regression.csv")
data.head()
X=data.iloc[:, :-1]
y=data['score']

model = BaggingRegressor(
                                base_estimator= DecisionTreeRegressor(max_depth=140),
                                 n_estimators = 150,
                                 max_samples = 1.0,
                                 max_features = 1.0
                        ) 
model.fit(X,y)
pred=model.predict(test)




df=pd.DataFrame()
df['Id'] =0
df['Predicted']=pred
df['Id'] = df.index
print(df)

df.to_csv('ans2.csv',index=False) 
X
# Out:
#         Id  Predicted
# 0        0  50.980391
# 1        1  60.994267
# 2        2  61.344727
# 3        3  48.313474
# 4        4  30.338995
# ...    ...        ...
# 1995  1995  36.745814
# 1996  1996  36.741054
# 1997  1997  37.121254
# 1998  1998  62.949772
# 1999  1999  59.250160
#
# [2000 rows x 2 columns]
#          acid0     acid1     acid2  chlorides  sulphates0  sulphates1  \
# 0     0.173077  0.127451  0.144578   0.053412    0.121951    0.327146
# 1     0.346154  0.186275  0.295181   0.083086    0.108014    0.341067
# 2     0.269231  0.343137  0.144578   0.091988    0.181185    0.348028
# 3     0.201923  0.205882  0.168675   0.077151    0.048780    0.250580
# 4     0.317308  0.166667  0.186747   0.121662    0.104530    0.341067
# ...        ...       ...       ...        ...         ...         ...
# 1995  0.384615  0.343137  0.295181   0.071217    0.121951    0.345708
# 1996  0.432692  0.058824  0.204819   0.097923    0.017422    0.088167
# 1997  0.250000  0.156863  0.162651   0.091988    0.114983    0.222738
# 1998  0.413462  0.107843  0.240964   0.083086    0.247387    0.396752
# 1999  0.317308  0.078431  0.216867   0.103858    0.062718    0.187935
#
#       sulphates2   density
# 0       0.104651  0.074995
# 1       0.372093  0.094274
# 2       0.372093  0.175631
# 3       0.232558  0.047812
# 4       0.337209  0.082707
# ...          ...       ...
# 1995    0.151163  0.161751
# 1996    0.209302  0.121265
# 1997    0.093023  0.039136
# 1998    0.139535  0.105842
# 1999    0.255814  0.169462
#
# [2000 rows x 8 columns]
